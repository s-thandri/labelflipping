# %%
import matplotlib.pyplot as plt

# %%
#List of times

IF_sex = [23.87,292.89,1085.63,1069.54]
UR_sex = [4,48.9,178.74,178.38]
MEU_sex = [23.92,292.63,1069.88,1061.88]
RF_sex = [4.01,49.58,179.18,179.52]

IF_race = [25.22,339.99,1193.96,2745.79]
UR_race = [4.23,55.89,199.82,456.73]
MEU_race = [25.29,337.95,1183.74,2729.6]
RF_race = [4.21,56.06,198.82,459.64]

IF_age = [26.4,482.83,4463.59,2713.85]
UR_age = [4.43,82.40,736.21,437.08]
MEU_age = [26.46,475.78,4356.28,2636.96]
RF_age = [4.33,77.61,725.56,466.51]

# %%
# Plotting the lines for each dataset
x_values = ['1k','5k','10k','15k']
plt.plot(x_values, IF_age, label='IF',color='red')
plt.plot(x_values, UR_age, label='UR', color='blue')
plt.plot(x_values, MEU_age, label='MEU', color='yellow')
plt.plot(x_values, RF_age, label='RF', color='black')

# Adding labels and title
plt.xlabel('Dataset size')
plt.ylabel('Time')
plt.title('Graph of Time vs Dataset Size for all Solutions with Age SA')

# Adding legend
plt.legend()

# Show the plot
plt.show()
